# %% [markdown]
# # Major Project

# %% [markdown]
# ### The given problem comes under Supervised Learning and of Classification type.

# %% [markdown]
# Let's load the dataframe by using pandas read_csv() method.

# %%
import pandas as pd

# %%
raw_df = pd.read_csv('diabetes.csv')

# %%
raw_df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %% [markdown]
# Let's look at the basic info of the data using info() method.

# %%
raw_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %% [markdown]
# Thus there are a total of 9 columns and 768 instances in the dataset.To look at the description of numeric columns in the dataset use describe() method.

# %%
raw_df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %% [markdown]
# We could observe ranges of values in different columns are different.

# %%
raw_df.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %% [markdown]
# Above are the names of columns in our dataset.

# %% [markdown]
# ## Data Visualization

# %%
import seaborn as sns

# %%
# %matplotlib inline

# %%
sns.scatterplot(x = raw_df.Pregnancies,y = raw_df.Age,hue=raw_df.Outcome)
# Out:
# <AxesSubplot:xlabel='Pregnancies', ylabel='Age'>

# %%
raw_df.Pregnancies.corr(raw_df.Outcome)
# Out:
# 0.22189815303398652

# %% [markdown]
# Here we could observe that women with more pregnancies and more age had diabetes.

# %%
sns.scatterplot(x = raw_df.Glucose,y = raw_df.Age,hue=raw_df.Outcome)
# Out:
# <AxesSubplot:xlabel='Glucose', ylabel='Age'>

# %%
raw_df.Glucose.corr(raw_df.Outcome)
# Out:
# 0.4665813983068733

# %% [markdown]
# Women with high Glucose levels likely to have diabetes.

# %%
sns.scatterplot(x = raw_df.BloodPressure,y = raw_df.Age,hue=raw_df.Outcome)
# Out:
# <AxesSubplot:xlabel='BloodPressure', ylabel='Age'>

# %%
raw_df.BloodPressure.corr(raw_df.Outcome)
# Out:
# 0.06506835955033273

# %% [markdown]
# Women with more age and high Bloodpressure levels likely to have diabetes.

# %%
sns.scatterplot(x = raw_df.SkinThickness,y = raw_df.Age,hue=raw_df.Outcome)
# Out:
# <AxesSubplot:xlabel='SkinThickness', ylabel='Age'>

# %%
raw_df.SkinThickness.corr(raw_df.Outcome)
# Out:
# 0.07475223191831942

# %% [markdown]
# Women with more skinthickness and more age likely to have diabetes.

# %%
sns.scatterplot(x = raw_df.Insulin,y = raw_df.Age,hue=raw_df.Outcome)
# Out:
# <AxesSubplot:xlabel='Insulin', ylabel='Age'>

# %%
raw_df.Insulin.corr(raw_df.Outcome)
# Out:
# 0.13054795488404788

# %% [markdown]
# Women with more Insulin levels and more age likely to have diabetes.

# %%
sns.scatterplot(x = raw_df.BMI,y = raw_df.Age,hue=raw_df.Outcome)
# Out:
# <AxesSubplot:xlabel='BMI', ylabel='Age'>

# %%
raw_df.BMI.corr(raw_df.Outcome)
# Out:
# 0.2926946626444451

# %% [markdown]
# Women with BMI more than 30 likely to have diabetes.

# %%
sns.scatterplot(x = raw_df.DiabetesPedigreeFunction,y = raw_df.Age,hue=raw_df.Outcome)
# Out:
# <AxesSubplot:xlabel='DiabetesPedigreeFunction', ylabel='Age'>

# %%
raw_df.DiabetesPedigreeFunction.corr(raw_df.Outcome)
# Out:
# 0.17384406565295973

# %% [markdown]
# women with more DiabetesPedigreeFunction and more age likely to have diabetes.

# %%
sns.scatterplot(x = raw_df.Age,y = raw_df.Age,hue=raw_df.Outcome)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Age'>

# %%
raw_df.Age.corr(raw_df.Outcome)
# Out:
# 0.23835598302719768

# %% [markdown]
# Women of age in between 40 and 60 likely to have diabetes.

# %% [markdown]
# ## Splitting the dataset.

# %%
from sklearn.model_selection import train_test_split

# %%
train,test = train_test_split(raw_df,test_size=0.2,random_state=0)

# %%
len(train)
# Out:
# 614

# %% [markdown]
# Our training dataset has 614 instances.

# %%
len(test)
# Out:
# 154

# %% [markdown]
# Our testing dataset has 154 instances.

# %%
import numpy as np

# %%
train_df = train.copy()

# %% [markdown]
# Let's create a copy of training dataset that it would not alter the original dataset.

# %%
test_df = test.copy()

# %% [markdown]
# Let's create a copy of testing dataset that it would not alter the original dataset.

# %%
train_df.replace({
    'Glucose':{0:np.NaN},
    'BloodPressure':{0:np.NaN},
    'SkinThickness':{0:np.NaN},
    'Insulin':{0:np.NaN},
    'BMI':{0:np.NaN},
},inplace=True)

# %% [markdown]
# Let's replace the zeroes in some of the columns with NaN as these values coludn't be zero.

# %%
test_df.replace({
    'Glucose':{0:np.NaN},
    'BloodPressure':{0:np.NaN},
    'SkinThickness':{0:np.NaN},
    'Insulin':{0:np.NaN},
    'BMI':{0:np.NaN},
},inplace=True)

# %%
input_cols = raw_df.columns[:-1]

# %%
input_cols
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age'],
#       dtype='object')

# %% [markdown]
# Above are the input columns to be given to our model.

# %%
target_col = raw_df.columns[-1]

# %%
target_col
# Out:
# 'Outcome'

# %% [markdown]
# Above are the targets to be predicted.

# %%
train_inputs = train_df[input_cols].copy()

# %%
train_targets = train_df[target_col].copy()

# %%
test_inputs = test_df[input_cols].copy()

# %%
test_targets = test_df[target_col].copy()

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 614 entries, 603 to 684
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               614 non-null    int64
#  1   Glucose                   610 non-null    float64
#  2   BloodPressure             585 non-null    float64
#  3   SkinThickness             432 non-null    float64
#  4   Insulin                   320 non-null    float64
#  5   BMI                       606 non-null    float64
#  6   DiabetesPedigreeFunction  614 non-null    float64
#  7   Age                       614 non-null    int64
#  8   Outcome                   614 non-null    int64
# dtypes: float64(6), int64(3)
# memory usage: 48.0 KB

# %%
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 154 entries, 661 to 380
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               154 non-null    int64
#  1   Glucose                   153 non-null    float64
#  2   BloodPressure             148 non-null    float64
#  3   SkinThickness             109 non-null    float64
#  4   Insulin                   74 non-null     float64
#  5   BMI                       151 non-null    float64
#  6   DiabetesPedigreeFunction  154 non-null    float64
#  7   Age                       154 non-null    int64
#  8   Outcome                   154 non-null    int64
# dtypes: float64(6), int64(3)
# memory usage: 12.0 KB

# %% [markdown]
# We could see that there are some missing values in some of the columns in both training and testing datasets.

# %% [markdown]
# ## Imputation

# %%
from sklearn.impute import SimpleImputer

# %%
imputer = SimpleImputer(strategy='median')

# %%
imputer.fit(train_inputs)
# Out:
# SimpleImputer(strategy='median')

# %%
train_inputs = imputer.transform(train_inputs)

# %%
test_inputs = imputer.transform(test_inputs)

# %% [markdown]
# ## Scaling

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
scaler.fit(train_inputs)
# Out:
# StandardScaler()

# %%
train_inputs = scaler.transform(train_inputs)

# %%
test_inputs = scaler.transform(test_inputs)

# %% [markdown]
# ## RandomForestClassifier

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf_model = RandomForestClassifier(random_state=0,n_jobs=-1)

# %%
rf_model.fit(train_inputs,train_targets)
# Out:
# RandomForestClassifier(n_jobs=-1, random_state=0)

# %%
rf_model.score(train_inputs,train_targets)
# Out:
# 1.0

# %% [markdown]
# Above is the training accuracy of our rf_model.

# %%
rf_model.score(test_inputs,test_targets)
# Out:
# 0.8181818181818182

# %% [markdown]
# Above is the testing accuracy of our model.

# %% [markdown]
# ## LogisticRegression

# %%
from sklearn.linear_model import LogisticRegression

# %%
log_reg = LogisticRegression(random_state=0)

# %%
log_reg.fit(train_inputs,train_targets)
# Out:
# LogisticRegression(random_state=0)

# %%
log_reg.score(train_inputs,train_targets)
# Out:
# 0.7638436482084691

# %% [markdown]
# Above is the training accuracy of our log_reg.

# %%
log_reg.score(test_inputs,test_targets)
# Out:
# 0.8116883116883117

# %% [markdown]
# Above is the testing accuracy of our lor_reg.
